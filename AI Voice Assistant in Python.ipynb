# %% [markdown]
# # 🎙️ AI Voice Assistant in Python

# %%
pip install pyttsx3 SpeechRecognition wikipedia pywhatkit pyaudio
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\aiza iqbal\anaconda3\lib\site-packages (2.99)
# Requirement already satisfied: SpeechRecognition in c:\users\aiza iqbal\anaconda3\lib\site-packages (3.16.1)
# Requirement already satisfied: wikipedia in c:\users\aiza iqbal\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: pywhatkit in c:\users\aiza iqbal\anaconda3\lib\site-packages (5.4)
# Requirement already satisfied: pyaudio in c:\users\aiza iqbal\anaconda3\lib\site-packages (0.2.14)
# Requirement already satisfied: comtypes in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pyttsx3) (1.4.16)
# Requirement already satisfied: pypiwin32 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pyttsx3) (311)
# Requirement already satisfied: typing-extensions in c:\users\aiza iqbal\anaconda3\lib\site-packages (from SpeechRecognition) (4.15.0)
# Requirement already satisfied: standard-aifc in c:\users\aiza iqbal\anaconda3\lib\site-packages (from SpeechRecognition) (3.13.0)
# Requirement already satisfied: audioop-lts in c:\users\aiza iqbal\anaconda3\lib\site-packages (from SpeechRecognition) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from wikipedia) (4.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from wikipedia) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2026.1.4)
# Requirement already satisfied: Pillow in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pywhatkit) (12.0.0)
# Requirement already satisfied: pyautogui in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pywhatkit) (0.9.54)
# Requirement already satisfied: Flask in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pywhatkit) (3.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.5)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from Flask->pywhatkit) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from Flask->pywhatkit) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from Flask->pywhatkit) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from Flask->pywhatkit) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from Flask->pywhatkit) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from Flask->pywhatkit) (3.1.3)
# Requirement already satisfied: colorama in c:\users\aiza iqbal\anaconda3\lib\site-packages (from click>=8.1.3->Flask->pywhatkit) (0.4.6)
# Requirement already satisfied: pymsgbox in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pyautogui->pywhatkit) (2.0.1)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pyautogui->pywhatkit) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pyautogui->pywhatkit) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pyautogui->pywhatkit) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pyautogui->pywhatkit) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\aiza iqbal\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui->pywhatkit) (0.2.0)
# Requirement already satisfied: pyperclip in c:\users\aiza iqbal\anaconda3\lib\site-packages (from mouseinfo->pyautogui->pywhatkit) (1.11.0)
# Requirement already satisfied: standard-chunk in c:\users\aiza iqbal\anaconda3\lib\site-packages (from standard-aifc->SpeechRecognition) (3.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pipwin
pipwin install pyaudio

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import wikipedia
import pywhatkit
import webbrowser

# Voice Engine
engine = pyttsx3.init()

def speak(text):
    print("Assistant:", text)
    engine.say(text)
    engine.runAndWait()

# Listen Function
def take_command():
    listener = sr.Recognizer()

    with sr.Microphone() as source:
        print("Listening...")
        voice = listener.listen(source)

    try:
        command = listener.recognize_google(voice)
        command = command.lower()
        print("You said:", command)
        return command

    except:
        return ""

# Main Task Function
def run_assistant():
    command = take_command()

    # Time
    if "time" in command:
        time = datetime.datetime.now().strftime('%I:%M %p')
        speak("Current time is " + time)

    # Wikipedia Search
    elif "who is" in command:
        person = command.replace("who is", "")
        info = wikipedia.summary(person, 2)
        speak(info)

    # Play YouTube
    elif "play" in command:
        song = command.replace("play", "")
        speak("Playing " + song)
        pywhatkit.playonyt(song)

    # Open Google
    elif "google" in command:
        speak("Opening Google")
        webbrowser.open("https://google.com")

    # Greeting
    elif "hello" in command:
        speak("Hello! I am your Python assistant.")

    else:
        speak("Sorry, I did not understand.")

# Run Assistant
while True:
    run_assistant()
